# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

pd.json_normalize(data['data'])
# Out:
#          id             name symbol             slug  num_market_pairs  \
# 0         1          Bitcoin    BTC          bitcoin             10496
# 1      1027         Ethereum    ETH         ethereum              7593
# 2       825      Tether USDt   USDT           tether             64141
# 3      1839              BNB    BNB              bnb              1690
# 4        52              XRP    XRP              xrp              1119
# ...     ...              ...    ...              ...               ...
# 4995  27909        Perpboost  BOOST        perpboost                 5
# 4996  22044  Halloween Floki   FLOH  halloween-floki                 2
# 4997  24093  Orbeon Protocol   ORBN  orbeon-protocol                 2
# 4998  23662         SB Group    SBG         sb-group                 4
# 4999  21493         GigaSwap   GIGA         gigaswap                 6
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2017-07-25T00:00:00.000Z
# 4     2013-08-04T00:00:00.000Z
# ...                        ...
# 4995  2023-08-23T11:58:51.000Z
# 4996  2022-10-03T06:10:56.000Z
# 4997  2023-03-27T04:00:43.000Z
# 4998  2023-03-03T00:09:22.000Z
# 4999  2022-08-20T14:12:07.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# ...                                                 ...           ...
# 4995                                                 []  1.000000e+09
# 4996                                                 []  1.000000e+12
# 4997                                                 []  8.880000e+08
# 4998                                                 []  1.000000e+10
# 4999                                                 []  1.000000e+11
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.952096e+07            19520956            False       NaN
# 1           1.202672e+08    120267199.240422             True       NaN
# 2           8.415423e+10  87625667477.022797             True       NaN
# 3           1.517050e+08    151705042.907611            False       NaN
# 4           5.344103e+10         99988362642            False       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00          1000000000            False       NaN
# 4996        0.000000e+00       1000000000000            False       NaN
# 4997        0.000000e+00           888000000            False       NaN
# 4998        0.000000e+00         10000000000            False       NaN
# 4999        0.000000e+00        100000000000            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4994                      2.000000e+08              65959.170130
# 4996      4995                      6.666667e+11              30041.748891
# 4997      4996                      6.038400e+08             590433.087874
# 4998      4997                      1.000000e+10              69043.808678
# 4999      4998                               NaN                       NaN
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2023-10-22T17:59:00.000Z     2.992834e+04
# 1           NaN  2023-10-22T17:59:00.000Z     1.636284e+03
# 2           NaN  2023-10-22T17:59:00.000Z     1.000431e+00
# 3           NaN  2023-10-22T17:59:00.000Z     2.155372e+02
# 4           NaN  2023-10-22T17:59:00.000Z     5.216341e-01
# ...         ...                       ...              ...
# 4995        NaN  2023-10-22T17:59:00.000Z     3.297959e-04
# 4996        NaN  2023-10-22T17:59:00.000Z     4.506262e-08
# 4997        NaN  2023-10-22T17:59:00.000Z     9.777972e-04
# 4998        NaN  2023-10-22T17:59:00.000Z     6.904381e-06
# 4999        NaN  2023-10-22T17:59:00.000Z     1.631522e-05
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             1.140751e+10                       7.4067
# 1             4.605523e+09                      17.4354
# 2             3.221819e+10                       7.8268
# 3             2.757330e+08                      12.3624
# 4             5.821586e+08                     -17.0605
# ...                    ...                          ...
# 4995          1.200821e+03                     -94.8197
# 4996          1.200785e+03                      65.8822
# 4997          1.199433e+03                   10893.0445
# 4998          1.196091e+03                     635.9754
# 4999          1.192940e+03                     -78.5914
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                        0.172426                     -0.725843
# 1                        0.260320                     -0.167926
# 2                       -0.009174                      0.007592
# 3                        0.307934                      0.251874
# 4                       -0.032215                     -0.690545
# ...                           ...                           ...
# 4995                    -0.217273                     -4.774613
# 4996                     0.311789                    -15.506765
# 4997                     0.312118                      8.555950
# 4998                     0.012862                     20.719465
# 4999                     0.333364                     -0.542236
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       10.917010                     12.567860
# 1                        5.049206                      2.750868
# 2                        0.022653                      0.036354
# 3                        2.723089                      2.372131
# 4                        6.770914                      1.495447
# ...                           ...                           ...
# 4995                   -75.503019                    -93.095079
# 4996                   -56.236047                    -21.362300
# 4997                    19.297796                     39.466394
# 4998                    20.995180                     36.659207
# 4999                    42.098749                     34.361547
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                        12.745967                      3.081675
# 1                        -2.761870                    -11.207265
# 2                         0.077359                      0.053507
# 3                        -0.733998                     -9.203119
# 4                        -1.892741                    -25.534875
# ...                            ...                           ...
# 4995                    -94.706401                    -94.502779
# 4996                    -21.362300                    -21.362300
# 4997                    -68.878757                    -80.854767
# 4998                      5.423109                    -33.446044
# 4999                     17.926930                      2.939746
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             5.842298e+11                         51.3660
# 1             1.967913e+11                         17.2965
# 2             8.419053e+10                          7.3994
# 3             3.269809e+10                          2.8739
# 4             2.787666e+10                          2.4501
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           6.284951e+11            NaN
# 1                           1.967913e+11            NaN
# 2                           8.766346e+10            NaN
# 3                           3.269809e+10            NaN
# 4                           5.216341e+10            NaN
# ...                                  ...            ...
# 4995                        3.297958e+05            NaN
# 4996                        4.506262e+04            NaN
# 4997                        8.682839e+05            NaN
# 4998                        6.904381e+04            NaN
# 4999                        1.631522e+06            NaN
#
#         quote.USD.last_updated  platform.id            platform.name  \
# 0     2023-10-22T17:59:00.000Z          NaN                      NaN
# 1     2023-10-22T17:59:00.000Z          NaN                      NaN
# 2     2023-10-22T17:59:00.000Z       1027.0                 Ethereum
# 3     2023-10-22T17:59:00.000Z          NaN                      NaN
# 4     2023-10-22T17:59:00.000Z          NaN                      NaN
# ...                        ...          ...                      ...
# 4995  2023-10-22T17:59:00.000Z      27716.0                     Base
# 4996  2023-10-22T17:59:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4997  2023-10-22T17:59:00.000Z       1027.0                 Ethereum
# 4998  2023-10-22T17:59:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4999  2023-10-22T17:59:00.000Z       1027.0                 Ethereum
#
#      platform.symbol platform.slug                      platform.token_address
# 0                NaN           NaN                                         NaN
# 1                NaN           NaN                                         NaN
# 2                ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                NaN           NaN                                         NaN
# 4                NaN           NaN                                         NaN
# ...              ...           ...                                         ...
# 4995             TBA          base  0x71E8f538f47397Cd9A544041555CaFC7A0Ce9ae3
# 4996             BNB           bnb  0x2c0e76DadE015bc390a13c1B80CC1bAFd9edD326
# 4997             ETH      ethereum  0xA7fBd9254f10F8e20a31a593C9E8BC0D041e15F6
# 4998             BNB           bnb  0x5E95A952a7f79f978585aFd54A053aF0f51372Fa
# 4999             ETH      ethereum  0x83249c6794bca5a77eb8c0af9f1a86e055459cea
#
# [5000 rows x 36 columns]
